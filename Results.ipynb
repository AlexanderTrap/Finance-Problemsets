# %% [markdown]
# # MPT results

# %% [markdown]
# Portfolio derived in other file.

# %% [markdown]
# Weights distribution of the optimal portfolio:
# <br>
# FB 5.3<br>
# GLD 53.3<br>
# GNUS 0.1<br>
# K 18.4<br>
# NTDOY 22.8<br>
#
# Expected return: 6.5 %<br>
# Variance: 0.031 %

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
from datetime import datetime
today=datetime.today().strftime('%Y-%m-%d')

# %%
tickers_list = ['NTDOY','GNUS','FB','K','GLD']
tickers_list=sorted(tickers_list)
tickers_list
# Out:
# ['FB', 'GLD', 'GNUS', 'K', 'NTDOY']

# %%
pf=np.array([5.3,53.3,0.1,18.4,22.8])/100

# %%
# Get the data for the stock AAPL
data = yf.download(tickers_list,'2020-06-15',today)
(data['Adj Close']).plot(figsize=(10,8),linestyle='-')
plt.title('Returns', fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Adj Close',fontsize=14)
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
d=yf.download(tickers_list,'2020-06-15',today,interval='1d')
data=d['Adj Close'].dropna()
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
df2 = data.iloc[[0, -1]]
df2
# Out:
#                     FB         GLD  GNUS          K      NTDOY
# Date
# 2020-06-15  232.500000  162.330002  4.52  65.489998  54.990002
# 2020-07-10  245.070007  169.190002  2.35  67.190002  57.290001

# %%
return_pct=df2.iloc[1]/df2.iloc[0]-1
return_pct
# Out:
# FB       0.054065
# GLD      0.042260
# GNUS    -0.480089
# K        0.025958
# NTDOY    0.041826
# dtype: float64

# %%
sum(return_pct*pf)
# Out:
# 0.03922228882158553
